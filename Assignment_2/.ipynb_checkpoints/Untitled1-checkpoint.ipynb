# %%
from __future__ import unicode_literals
import requests
from requests_oauthlib import OAuth1
import argparse
import json
from time import gmtime, strftime
import os
import glob

# %%
#url = 'https://api.twitter.com/1.1/account/verify_credentials.json'
API_KEY = 'slbBbLG1sh2hMg1MuIhk8fzNB'
API_SECRET = 'Cl59tZu1Rww9MB6lxq5qxyX6wFAm72DBEIsbVNZPWwzQnhwLat'
ACCESS_TOKEN = '4786768341-9KkLc5dn7qhIn220YeffLyLQJQlDr8EceB3Y7B0'
ACCESS_TOKEN_SECRET = 'ko0ELXDAJ1WJro6foeU7T5gjxE4c8340eeKjquXssVtFq'

auth = OAuth1(API_KEY, API_SECRET, ACCESS_TOKEN, ACCESS_TOKEN_SECRET)

#requests.get(url, auth=auth)

userIn = input("Enter topic you want to search:")

searchUrl = "https://api.twitter.com/1.1/search/tweets.json?lang=en&result_type=mix&count=1500&q=" + userIn;

r = requests.get(searchUrl, auth=auth, stream = True)

#print(type(r))
#for tweet in r.json():
    # print (tweet)
    
def new_folder(userIn):
    if not os.path.exists(userIn):
        os.makedirs(userIn)
        
for directory in os.listdir(): 
    if userIn!=directory:
        new_folder(userIn) 
                
fname = strftime("%Y-%m-%d-%H-%M-%S", gmtime())
fname = userIn + "\\" + fname + '.json';

rec = dict(r.json())
json.dumps(rec)
with open(fname ,'w')as f:
    json.dump(rec, f)
P = json.load(open(fname))
print(P)
# Out:
# Enter topic you want to search:hillary
# {'search_metadata': {'max_id': 790742102405623808, 'refresh_url': '?since_id=790742102405623808&q=hillary&lang=en&result_type=mix&include_entities=1', 'query': 'hillary', 'next_results': '?max_id=790742073842421759&q=hillary&lang=en&count=100&include_entities=1&result_type=mix', 'completed_in': 0.11, 'since_id_str': '0', 'since_id': 0, 'count': 100, 'max_id_str': '790742102405623808'}, 'statuses': [{'text': 'RT @WeNeedTrump: Insane crowd in Tampa Bay tonight. Tell me again how Hillary has Florida in the bag... #MakeAmericaGreatAgain https://t.co…', 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'favorite_count': 0, 'user': {'time_zone': None, 'favourites_count': 640, 'url': None, 'profile_background_color': 'C0DEED', 'profile_image_url': 'http://pbs.twimg.com/profile_images/789951230311141377/Aeaaly8R_normal.jpg', 'statuses_count': 2196, 'default_profile': True, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'is_translation_enabled': False, 'id': 2262321421, 'contributors_enabled': False, 'id_str': '2262321421', 'has_extended_profile': False, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2262321421/1477173926', 'follow_request_sent': False, 'geo_enabled': False, 'profile_text_color': '333333', 'location': '', 'verified': False, 'utc_offset': None, 'description': '', 'following': False, 'created_at': 'Thu Dec 26 04:39:15 +0000 2013', 'name': 'charles  r    lacy', 'followers_count': 154, 'default_profile_image': False, 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'notifications': False, 'screen_name': '_chuck956', 'friends_count': 120, 'profile_background_tile': False, 'lang': 'en', 'translator_type': 'none', 'is_translator': False, 'profile_sidebar_border_color': 'C0DEED', 'protected': False, 'profile_sidebar_fill_color': 'DDEEF6', 'listed_count': 2, 'profile_link_color': '0084B4', 'entities': {'description': {'urls': []}}, 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/789951230311141377/Aeaaly8R_normal.jpg', 'profile_use_background_image': True}, 'in_reply_to_status_id': None, 'in_reply_to_screen_name': None, 'is_quote_status': False, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'id_str': '790742102405623808', 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'contributors': None, 'truncated': False, 'retweeted_status': {'text': 'Insane crowd in Tampa Bay tonight. Tell me again how Hillary has Florida in the bag... #MakeAmericaGreatAgain https://t.co/TA0c6PCZsc', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'extended_entities': {'media': [{'id': 790700685557899264, 'id_str': '790700685557899264', 'url': 'https://t.co/TA0c6PCZsc', 'media_url_https': 'https://pbs.twimg.com/media/CvkiFY5WIAAxdxC.jpg', 'indices': [110, 133], 'expanded_url': 'https://twitter.com/WeNeedTrump/status/790700697968861184/photo/1', 'display_url': 'pic.twitter.com/TA0c6PCZsc', 'media_url': 'http://pbs.twimg.com/media/CvkiFY5WIAAxdxC.jpg', 'type': 'photo', 'sizes': {'large': {'h': 666, 'w': 2048, 'resize': 'fit'}, 'small': {'h': 221, 'w': 680, 'resize': 'fit'}, 'medium': {'h': 390, 'w': 1200, 'resize': 'fit'}, 'thumb': {'h': 150, 'w': 150, 'resize': 'crop'}}}]}, 'favorite_count': 2859, 'user': {'time_zone': 'Central Time (US & Canada)', 'favourites_count': 3081, 'url': 'https://t.co/O5S0tGtvtj', 'profile_background_color': '000000', 'profile_image_url': 'http://pbs.twimg.com/profile_images/622657650635898880/sRnv9Ilr_normal.jpg', 'statuses_count': 5589, 'default_profile': False, 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'is_translation_enabled': False, 'id': 3284112337, 'contributors_enabled': False, 'id_str': '3284112337', 'has_extended_profile': False, 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3284112337/1468134358', 'follow_request_sent': False, 'geo_enabled': F ...

# %%
from textblob import TextBlob

count = 0
positive = 0
negative = 0
neutral = 0

for filename in glob.glob(userIn + r"\*.json"):
    with open(filename, 'r') as f:
        P = json.load(f)

        for items in P["statuses"]:
    
            blob = TextBlob(items["text"])
            #print(items["text"])
    
            count += 1
            total = 0
    
            for sentence in blob.sentences:
                blob.tags
                blob.noun_phrases
                value = sentence.sentiment.polarity
                total += value
    
            if(total > 0):
                positive = positive + 1 
            elif total < 0:
                negative +=1
            else:
                neutral +=1
        
            #print(positive)
            #print(negative)
            #print(neutral)
            #print("total: {val}".format(val = total))

#print(count)
print("Out of total number of {val} tweets on the given topic, following results were obtained:".format(val = count))
print("{pos} percentage of people were postive,".format(pos = (positive/count)*100))
print("{neg} percentage of people were negative,".format(neg = (negative/count)*100))
print("{neu} percentage of people were neutral about this topic".format(neu = (neutral/count)*100))
# Out:
# Out of total number of 400 tweets on the given topic, following results were obtained:
# 29.5 percentage of people were postive,
# 26.0 percentage of people were negative,
# 44.5 percentage of people were neutral about this topic

# %%
import gmplot

count = 0
total = 0
latitudes = []
longitudes = []
for filename in glob.glob(userIn + r"\*.json"):
    with open(filename, 'r') as f:
        P = json.load(f)
        for items in P["statuses"]:
            try:
                #print(items["retweeted_status"]["place"])
                if(items["retweeted_status"]["place"] is not None):
                    latitudes.append(items["retweeted_status"]["place"]["bounding_box"]["coordinates"][0][0][0])
                    longitudes.append(items["retweeted_status"]["place"]["bounding_box"]["coordinates"][0][0][1])
                #print(items["place"])
            except KeyError:
                #print(items["place"])
                if(items["place"] is not None):
                    latitudes.append(items["place"]["bounding_box"]["coordinates"][0][0][0])
                    longitudes.append(items["place"]["bounding_box"]["coordinates"][0][0][1])
                    
gmap = gmplot.GoogleMapPlotter(latitudes[0],longitudes[0],20)
gmap.scatter(more_lats, more_lngs, '#3B0B39', size=40, marker=True)
gmap.draw('map.html')
print(count)
# Out:
# 0

# %%
d = {}
d['Sun'] = d['Mon'] = d['Tue'] = d['Wed'] = d['Thu'] = d['Fri'] = d['Sat'] = 0

for filename in glob.glob(userIn + r"\*.json"):
    with open(filename, 'r') as f:
        P = json.load(f)

        for items in P["statuses"]:
            createdTime = items["created_at"]
            dateStr = "" + createdTime[0:3];
            d[dateStr] += 1

                  
sorted(d.values())
days = list(d.keys())
#print(days)
print("People talk more about this topic on :")
#print(d)
k = sorted(d, key=d.get, reverse=True)[:2]

print(k)
# Out:
# People talk more about this topic on :
# ['Mon', 'Tue']

# %%
favList = []

for filename in glob.glob(userIn + r"\*.json"):
    with open(filename, 'r') as f:
        P = json.load(f)
        
        for items in P["statuses"]:
            try:
                li = []
                retweeted_favourite_count = items['retweeted_status']['favorite_count']
                tweet = items["text"]
                li.append(retweeted_favourite_count)
                li.append(tweet)
                favList.append(li)
            except KeyError:
                retweeted_favourite_count = 0



                
temp = []
favList.sort(key=lambda x: x[0], reverse = True)
li = ['Total Count', 'Tweet'] 
item = []
item.append(li)
favList[0:0] = item
print("Most favorite tweet is:")
print(favList[1][1])
print("\n\"Open .csv file for more detailed summary\"")
import csv

import pyexcel
pyexcel.save_as(array = favList, dest_file_name = userIn + r'\MostFavoriteToLeastFavorite.csv')
# Out:
# Most favorite tweet is:
# RT @HillaryClinton: RT if you’re proud of Hillary tonight. #DebateNight #SheWon https://t.co/H7CJep7APX
#
# "Open .csv file for more detailed summary"

# %%
hashtagList = []

for filename in glob.glob(userIn + r"\*.json"):
    with open(filename, 'r') as f:
        P = json.load(f)

        for items in P["statuses"]:
            hashtagList.append(items["entities"]["hashtags"])
            
tagList = []
tagCount = {}
for items in hashtagList:
    for item in items:
        hashtag = "" + item["text"]
        hashtag = hashtag.lower()
        if hashtag not in tagCount:
            tagCount[hashtag] = 0
        else:
            tagCount[hashtag] += 1

k = sorted(tagCount, key=tagCount.get, reverse=True)[:3]
print("Top 3 hashtags for this topic are - {val}, {val2}, {val3}".format(val = k[0], val2 = k[1], val3 = k[2]))
# Out:
# Top 3 hashtags for this topic are - hillary, wikileaks, draintheswamp
